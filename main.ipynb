# %%
# main.py
from store import DataFrameStore
from agent import run_query
from config import THREAD_ID
import os
from tools import *

# %%
def initialize():
    os.makedirs("plots", exist_ok=True)
    DataFrameStore.load()
    print("\n🤖 Aivee - Time Series Analysis Agent is Ready!\n")

# %%
initialize()
# Out:
# ✅ Loaded 1000 rows and 212 columns
#
# 🤖 Aivee - Time Series Analysis Agent is Ready!

# %%
run_query(query="hi", thread_id=THREAD_ID)
# Out:
# 'Hello! I am Aivee, an AI agent designed to help you analyze time series data. How can I assist you today?'

# %%
run_query(query="Give me mean", thread_id=THREAD_ID)
# Out:
# "Oops, it looks like I don't have the column name yet. Could you please provide the column you would like me to calculate the mean for?"

# %%
run_query(query="441PIC001", thread_id=THREAD_ID)
# Out:
# "The mean value for the '441PIC001' column is 4.4622. Let me know if you need anything else!"

# %%
run_query(query="give me below 60th to 80th percentile line plot", thread_id=THREAD_ID)
# Out:
# 'Hmm, it looks like there was an issue generating the plot. Let me know if you would like me to try a different visualization or if you have any other requests!'

# %%
from store import DataFrameStore

def initialize():
    os.makedirs("plots", exist_ok=True)
    DataFrameStore.load()
    print("\n🤖 Aivee - Time Series Analysis Agent is Ready!\n")

initialize()
df = DataFrameStore.get_df()
col = "441PIC001.PV"
# Out:
# ✅ Loaded 1000 rows and 212 columns
#
# 🤖 Aivee - Time Series Analysis Agent is Ready!

# %%
df[col].describe()
# Out:
# count    1000.000000
# mean        4.462215
# std         0.001881
# min         4.452125
# 25%         4.461202
# 50%         4.462009
# 75%         4.463337
# max         4.472013
# Name: 441PIC001.PV, dtype: float64

# %%
from store import DataFrameStore

def initialize():
    os.makedirs("plots", exist_ok=True)
    DataFrameStore.load()
    print("\n🤖 Aivee - Time Series Analysis Agent is Ready!\n")

initialize()
df = DataFrameStore.get_df()
col = "441PIC001.PV"

print(plot_tool.invoke({
    "columns": [col],
    "plot_type": "line",
    "filter_type": "percentile_range",
    "low_threshold": 4.461202,
    "high_threshold": 4.463337,
    "count": 300
}))

# %%
df = DataFrameStore.get_df()
col = "441PIC001.PV"

plot_tool.invoke({
    "columns": [col],
    "plot_type": "line",
    "filter_type": "percentile_range",
    "low_threshold": 4.5,
    "high_threshold": 5.5,
    "count": 80
})
# Out:
# 'No data after applying filter'

# %%
run_query(query="Yes", thread_id=THREAD_ID)
# Out:
# "The plot has been generated showing the data for the '441PIC001' column, filtered to include only the values between the 20th and 70th percentiles."

# %%
441PIC001

# %%
give me above 20th percentile to 50th percentile plot

# %%
give me above 70th percentile plot

# %%
# Out:
# c:\Users\sushant.mane\Tasks\Time-Series-Agent2\tools.py:239: UserWarning: Starting a Matplotlib GUI outside of the main thread will likely fail.
#   plt.figure(figsize=(10, 6))
# c:\Users\sushant.mane\Tasks\Time-Series-Agent2\tools.py:263: UserWarning: Starting a Matplotlib GUI outside of the main thread will likely fail.
#   plt.show()
# "The plot has been generated, showing the values for the '441PIC001.PV' column between the 20th and 60th percentiles."

# %%
4.4625
4.4617
4.4601
# Out:
# 4.4625

# %%
run_query(query="give me the percentile line plot for below 30 percentiles value", thread_id=THREAD_ID)
# Out:
# [values] {'messages': [HumanMessage(content='441PIC001.OP', additional_kwargs={}, response_metadata={}, id='e25675b4-5d7e-4198-a313-74cd36e97b4f'), AIMessage(content="Hello, I'm Aivee, an AI assistant designed by Tridiagonal.ai to help with time series data analysis. Could you please provide me with more details about your request? What would you like me to do with the '441PIC001.OP' data?", additional_kwargs={'usage': {'prompt_tokens': 1012, 'completion_tokens': 63, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 1075}, 'stop_reason': 'end_turn', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0'}, response_metadata={'usage': {'prompt_tokens': 1012, 'completion_tokens': 63, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 1075}, 'stop_reason': 'end_turn', 'model_id': 'anthropic.claude-3-haiku-20240307-v1:0', 'model_provider': 'bedrock', 'model_name': 'anthropic.claude-3-haiku-20240307-v1:0'}, name='timeseries_agent', id='lc_
# ...

# %%
24.4832
# Out:
# 24.4832

# %%
d = initialize()
# Out:
# ✅ Loaded 1000 rows and 212 columns
#
# 🤖 Aivee - Time Series Analysis Agent is Ready!

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\sushant.mane\Tasks\Time-Series-Agent2\data\new_data.csv")
df['441PIC001.OP'].mean()
# Out:
# np.float64(24.48316259391)
